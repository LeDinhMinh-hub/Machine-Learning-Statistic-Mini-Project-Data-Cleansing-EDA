# %% [markdown]
# <a href="https://colab.research.google.com/github/LeDinhMinh-hub/Machine_Learning_Statistic-Mini_Project-Data_Cleansing_EDA/blob/main/%5BMini_project_2%5D_L%C3%AA_%C4%90%C3%ACnh_Minh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Import File

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Importing the required libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# ##Loading the data into the data frame.

# %%
df = pd.read_csv('/content/drive/MyDrive/Bản sao của mini-project2.csv')

# %%
df.head(5) # To display the top 5 rows
# Out:
#    Unnamed: 0.1  Unnamed: 0 trans_date_trans_time           cc_num  \
# 0          2449        2449   2019-01-02 01:06:37    4613314721966
# 1          2472        2472   2019-01-02 01:47:29  340187018810220
# 2          2523        2523   2019-01-02 03:05:23  340187018810220
# 3          2546        2546   2019-01-02 03:38:03    4613314721966
# 4          2553        2553   2019-01-02 03:55:47  340187018810220
#
#                            merchant       category     amt  first    last  \
# 0            fraud_Rutherford-Mertz    grocery_pos  281.06  Jason  Murphy
# 1  fraud_Jenkins, Hauck and Friesen  gas_transport   11.52  Misty    Hart
# 2            fraud_Goodwin-Nitzsche    grocery_pos  276.31  Misty    Hart
# 3            fraud_Erdman-Kertzmann  gas_transport    7.03  Jason  Murphy
# 4                fraud_Koepp-Parker    grocery_pos  275.73  Misty    Hart
#
#   gender  ...      lat     long city_pop                       job  \
# 0      M  ...  35.9946 -81.7266      885            Soil scientist
# 1      F  ...  29.4400 -98.4590  1595797  Horticultural consultant
# 2      F  ...  29.4400 -98.4590  1595797  Horticultural consultant
# 3      M  ...  35.9946 -81.7266      885            Soil scientist
# 4      F  ...  29.4400 -98.4590  1595797  Horticultural consultant
#
#           dob                         trans_num   unix_time  merch_lat  \
# 0  1988-09-15  e8a81877ae9a0a7f883e15cb39dc4022  1325466397  36.430124
# 1  1960-10-28  bc7d41c41103877b03232f03f1f8d3f5  1325468849  29.819364
# 2  1960-10-28  b98f12f4168391b2203238813df5aa8c  1325473523  29.273085
# 3  1988-09-15  397894a5c4c02e3c61c784001f0f14e4  1325475483  35.909292
# 4  1960-10-28  7863235a750d73a244c07f1fb7f0185a  1325476547  29.786426
#
#   merch_long is_fraud
# 0 -81.179483        1
# 1 -99.142791        1
# 2 -98.836360        1
# 3 -82.091010        1
# 4 -98.683410        1
#
# [5 rows x 24 columns]

# %%
df.tail(5)   # To display the botton 5 rows
# Out:
#        Unnamed: 0.1  Unnamed: 0 trans_date_trans_time               cc_num  \
# 97743        503932      503932   2019-08-06 18:40:39     4449530933957323
# 97744         64323       64323   2019-02-07 19:04:40     4740713119940984
# 97745        770307      770307   2019-11-25 16:06:19  4358137750029944984
# 97746        387704      387704   2019-06-26 20:17:53     4514242065619750
# 97747        678744      678744   2019-10-16 13:30:15         676195318214
#
#                                 merchant        category    amt    first  \
# 97743  fraud_Mante, Luettgen and Hackett  health_fitness   9.86  Felicia
# 97744                 fraud_Connelly PLC     food_dining  40.46  Heather
# 97745                    fraud_Terry Ltd            home  74.66     Dawn
# 97746              fraud_Goyette-Gerhold       kids_pets  50.78    Janet
# 97747      fraud_Weber, Thiel and Hammes       kids_pets  12.02   Brandy
#
#             last gender  ...      lat      long city_pop  \
# 97743      Mckee      F  ...  38.2427 -122.9145      337
# 97744      Hines      F  ...  41.1901  -74.0436     9993
# 97745   Stephens      F  ...  42.7012  -92.0762       53
# 97746  Carpenter      F  ...  41.4247 -105.4781    35371
# 97747      Quinn      F  ...  29.6047  -96.5249      106
#
#                              job         dob  \
# 97743  Occupational psychologist  1954-07-05
# 97744        Pensions consultant  1962-10-16
# 97745       Sports administrator  1972-10-05
# 97746             Pilot, airline  1988-09-02
# 97747         Editor, film/video  1983-07-24
#
#                               trans_num   unix_time  merch_lat  merch_long  \
# 97743  1e113a065f2f86e403cc9d691012d46b  1344278439  38.591623 -122.298122
# 97744  470dcc55408c04af882ddc51f1f8bd8b  1328641480  40.326619  -73.099194
# 97745  722d50a7e9541269a90b22626d03ed64  1353859579  43.260232  -91.900022
# 97746  32473318cb527245e46d72d48e3ff9ca  1340741873  40.773936 -105.779345
# 97747  872da5a8081720fdc199e1f65b1df2bb  1350394215  30.092941  -97.210084
#
#       is_fraud
# 97743        0
# 97744        0
# 97745        0
# 97746        0
# 97747        0
#
# [5 rows x 24 columns]

# %% [markdown]
# ##Checking the types of data

# %%
df.dtypes
# Out:
# Unnamed: 0.1               int64
# Unnamed: 0                 int64
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                  int64
# merch_lat                float64
# merch_long               float64
# is_fraud                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97748 entries, 0 to 97747
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           97748 non-null  int64
#  1   Unnamed: 0             97748 non-null  int64
#  2   trans_date_trans_time  97748 non-null  object
#  3   cc_num                 97748 non-null  int64
#  4   merchant               97748 non-null  object
#  5   category               97748 non-null  object
#  6   amt                    97748 non-null  float64
#  7   first                  97748 non-null  object
#  8   last                   97748 non-null  object
#  9   gender                 97748 non-null  object
#  10  street                 97748 non-null  object
#  11  city                   97748 non-null  object
#  12  state                  97748 non-null  object
#  13  zip                    97748 non-null  int64
#  14  lat                    97748 non-null  float64
#  15  long                   97748 non-null  float64
#  16  city_pop               97748 non-null  int64
#  17  job                    97748 non-null  object
#  18  dob                    97748 non-null  object
#  19  trans_num              97748 non-null  object
#  20  unix_time              97748 non-null  int64
#  21  merch_lat              97748 non-null  float64
#  22  merch_long             97748 non-null  float64
#  23  is_fraud               97748 non-null  int64
# dtypes: float64(5), int64(7), object(12)
# memory usage: 17.9+ MB

# %% [markdown]
# ##Dropping irrelevant columns

# %%
df = df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
df.head(5)
# Out:
#   trans_date_trans_time           cc_num                          merchant  \
# 0   2019-01-02 01:06:37    4613314721966            fraud_Rutherford-Mertz
# 1   2019-01-02 01:47:29  340187018810220  fraud_Jenkins, Hauck and Friesen
# 2   2019-01-02 03:05:23  340187018810220            fraud_Goodwin-Nitzsche
# 3   2019-01-02 03:38:03    4613314721966            fraud_Erdman-Kertzmann
# 4   2019-01-02 03:55:47  340187018810220                fraud_Koepp-Parker
#
#         category     amt  first    last gender                     street  \
# 0    grocery_pos  281.06  Jason  Murphy      M  542 Steve Curve Suite 011
# 1  gas_transport   11.52  Misty    Hart      F  27954 Hall Mill Suite 575
# 2    grocery_pos  276.31  Misty    Hart      F  27954 Hall Mill Suite 575
# 3  gas_transport    7.03  Jason  Murphy      M  542 Steve Curve Suite 011
# 4    grocery_pos  275.73  Misty    Hart      F  27954 Hall Mill Suite 575
#
#             city  ...      lat     long  city_pop                       job  \
# 0  Collettsville  ...  35.9946 -81.7266       885            Soil scientist
# 1    San Antonio  ...  29.4400 -98.4590   1595797  Horticultural consultant
# 2    San Antonio  ...  29.4400 -98.4590   1595797  Horticultural consultant
# 3  Collettsville  ...  35.9946 -81.7266       885            Soil scientist
# 4    San Antonio  ...  29.4400 -98.4590   1595797  Horticultural consultant
#
#           dob                         trans_num   unix_time  merch_lat  \
# 0  1988-09-15  e8a81877ae9a0a7f883e15cb39dc4022  1325466397  36.430124
# 1  1960-10-28  bc7d41c41103877b03232f03f1f8d3f5  1325468849  29.819364
# 2  1960-10-28  b98f12f4168391b2203238813df5aa8c  1325473523  29.273085
# 3  1988-09-15  397894a5c4c02e3c61c784001f0f14e4  1325475483  35.909292
# 4  1960-10-28  7863235a750d73a244c07f1fb7f0185a  1325476547  29.786426
#
#    merch_long  is_fraud
# 0  -81.179483         1
# 1  -99.142791         1
# 2  -98.836360         1
# 3  -82.091010         1
# 4  -98.683410         1
#
# [5 rows x 22 columns]

# %% [markdown]
# ##Dropping the duplicate rows

# %%
df.shape
# Out:
# (97748, 22)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 22)

# %%
df.count()
# Out:
# trans_date_trans_time    97748
# cc_num                   97748
# merchant                 97748
# category                 97748
# amt                      97748
# first                    97748
# last                     97748
# gender                   97748
# street                   97748
# city                     97748
# state                    97748
# zip                      97748
# lat                      97748
# long                     97748
# city_pop                 97748
# job                      97748
# dob                      97748
# trans_num                97748
# unix_time                97748
# merch_lat                97748
# merch_long               97748
# is_fraud                 97748
# dtype: int64

# %% [markdown]
# ##Dropping the missing or null values.

# %%
df.isnull().sum()
# Out:
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# trans_date_trans_time    97748
# cc_num                   97748
# merchant                 97748
# category                 97748
# amt                      97748
# first                    97748
# last                     97748
# gender                   97748
# street                   97748
# city                     97748
# state                    97748
# zip                      97748
# lat                      97748
# long                     97748
# city_pop                 97748
# job                      97748
# dob                      97748
# trans_num                97748
# unix_time                97748
# merch_lat                97748
# merch_long               97748
# is_fraud                 97748
# dtype: int64

# %% [markdown]
# ##Check fraud transaction

# %%
df_check = df.groupby('is_fraud')[['cc_num']].count().reset_index()
df_check['%'] = (df_check['cc_num']/sum(df_check['cc_num']))
df_check.rename(columns = {'cc_num':'total'},inplace=True)
df_check
# Out:
#    is_fraud  total         %
# 0         0  90242  0.923211
# 1         1   7506  0.076789

# %% [markdown]
# The ration of label 1 on total is 7.6% &#8594; We can continue with the EDA and ML model

# %%
df.describe()
# Out:
#              cc_num           amt           zip           lat          long  \
# count  9.774800e+04  97748.000000  97748.000000  97748.000000  97748.000000
# mean   4.103967e+17    102.832444  48776.833807     38.525509    -90.210550
# std    1.298122e+18    217.047969  26937.012679      5.079548     13.799118
# min    6.041621e+10      1.000000   1257.000000     20.027100   -165.672300
# 25%    1.800429e+14     10.567500  26041.000000     34.668900    -96.790900
# 50%    3.521815e+15     50.160000  48088.000000     39.342600    -87.458100
# 75%    4.642255e+15     91.782500  72042.000000     41.894800    -80.128400
# max    4.992346e+18  15047.030000  99783.000000     66.693300    -67.950300
#
#            city_pop     unix_time     merch_lat    merch_long      is_fraud
# count  9.774800e+04  9.774800e+04  97748.000000  97748.000000  97748.000000
# mean   8.830390e+04  1.349189e+09     38.524928    -90.210050      0.076789
# std    2.985310e+05  1.287321e+07      5.114803     13.813079      0.266258
# min    2.300000e+01  1.325376e+09     19.031242   -166.654993      0.000000
# 25%    7.430000e+02  1.338657e+09     34.749667    -96.864098      0.000000
# 50%    2.471000e+03  1.349214e+09     39.349543    -87.391641      0.000000
# 75%    2.047800e+04  1.359276e+09     41.944618    -80.207857      0.000000
# max    2.906700e+06  1.371817e+09     67.510267    -66.980744      1.000000

# %% [markdown]
# ##Define type of data

# %%
df.dtypes.unique()
# Out:
# array([dtype('O'), dtype('int64'), dtype('float64')], dtype=object)

# %%
obj_cols = df.select_dtypes(include=['object'])
num_cols = df.select_dtypes(exclude=['object'])

# %%
num_cols.nunique()
# Out:
# cc_num          983
# amt           25048
# zip             970
# lat             968
# long            969
# city_pop        879
# unix_time     97609
# merch_lat     97438
# merch_long    97627
# is_fraud          2
# dtype: int64

# %% [markdown]
# As showing the unique values of each numeric columns, there's no columns have low unique values (less than 10 values) &#8594; There's no column has dtype = numeric but have category meaning.

# %% [markdown]
# ##Feature Engineering & EDA

# %% [markdown]
# ###Distribution

# %%
colnames = ['cc_num', 'amt', 'city_pop','is_fraud']
for col in colnames:
    fig, ax = plt.subplots(figsize=(12, 3))
    sns.distplot(df[col])
    ax.set_title('Distribution of %s' % col)
    plt.show()
# Out:
# <ipython-input-19-73487173c772>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-19-73487173c772>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-19-73487173c772>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# <ipython-input-19-73487173c772>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])

# %% [markdown]
# From this distribution, we can see:
# * amt: most amount of transactions centralize from 0 to 1000 &#8594; it can have some outliers in this columns, it can related to fraud transactions
# * city_pop: most the city population centralize from < 100000 to 200000 &#8594; in practice, population of the city may not affect the fraud transaction. However, we still check if any

# %%
sns.displot(data=df, x="amt",kde =True)

# %%
sns.displot(data=df, x="amt", kind="kde")

# %% [markdown]
# ###Check correlation

# %%
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])

# %%
df_numeric = df.select_dtypes(include=[int, float])

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_numeric.corr(),ax=ax,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Based on correlation heatmap, we see the amt has high correlation with is_fraud

# %% [markdown]
# ###Bar plot

# %%
df1=df

# %%
df1['trans_date_trans_time'] = pd.to_datetime(df1['trans_date_trans_time'])

# %%
df1['tns_hour'] = df1['trans_date_trans_time'].apply(lambda x: pd.to_datetime(x,format='%Y-%m-%d %H:%M:%S.%f').hour)
df1[['trans_date_trans_time','tns_hour']]
# Out:
#       trans_date_trans_time  tns_hour
# 0       2019-01-02 01:06:37         1
# 1       2019-01-02 01:47:29         1
# 2       2019-01-02 03:05:23         3
# 3       2019-01-02 03:38:03         3
# 4       2019-01-02 03:55:47         3
# ...                     ...       ...
# 97743   2019-08-06 18:40:39        18
# 97744   2019-02-07 19:04:40        19
# 97745   2019-11-25 16:06:19        16
# 97746   2019-06-26 20:17:53        20
# 97747   2019-10-16 13:30:15        13
#
# [97748 rows x 2 columns]

# %%
# Function to calculate percentage of fraud by hour
def count_percentage(df1, tns_hour, is_fraud, cc_num):
    # Group by hour and calculate fraud count and total count
    grouped = df1.groupby(tns_hour).agg(
        fraud_count=(is_fraud, 'sum'),
        total_count=(cc_num, 'count')
    ).reset_index()

    # Calculate percentage of fraud
    grouped['%'] = (grouped['fraud_count'] / grouped['total_count']) * 100

    return grouped

# %%
time_df = count_percentage(df1,'tns_hour','is_fraud','cc_num')
sns.barplot(data=time_df, x='tns_hour', y='%')
# Out:
# <Axes: xlabel='tns_hour', ylabel='%'>

# %% [markdown]
# The time of fraudulent transactions usually occurs at 22 to 23 hours.

# %% [markdown]
# ###Box plot

# %%
data=df

# %%
sns.boxplot(data=data,x=data['is_fraud'],y=data['amt'])
# Out:
# <Axes: xlabel='is_fraud', ylabel='amt'>

# %% [markdown]
# * For fraud trns, the number of total amount centralize from about 200 - 2000
# * For non-fraud, the number of total amount have more higher values

# %% [markdown]
# ##Category Features

# %%
def count_percentage_tns(df, column, target, count):
    '''
    This function to create the table calculate the percentage of fraud/non-fraud transaction on total transaction group by category values

    '''

    # Create 2 dataframes of fraud and non-fraud
    fraud = df[df[target]==1].groupby(column)[[count]].count().reset_index().sort_values(ascending=False, by = count)
    not_fraud = df[df[target]==0].groupby(column)[[count]].count().reset_index().sort_values(ascending=False, by = count)

    #Merge 2 dataframe into one:
    cate_df = fraud.merge(not_fraud, on = column , how = 'outer')
    cate_df = cate_df.fillna(0)
    cate_df.rename(columns = {count+'_x':'fraud',count+'_y':'not_fraud'}, inplace = True)

    #Caculate the percentage:
    cate_df['%'] = cate_df['fraud']/(cate_df['fraud']+cate_df['not_fraud'])

    return cate_df

def count_percentage_cc(df, column, target, count):
    '''
    This function to create the table calculate the percentage of fraud/non-fraud card number on total card number group by category values

    '''

    # Create 2 dataframes of fraud and non-fraud
    fraud = df[df[target]==1].groupby(column)[[count]].nunique().reset_index().sort_values(ascending=False, by = count)
    not_fraud = df[df[target]==0].groupby(column)[[count]].nunique().reset_index().sort_values(ascending=False, by = count)

    #Merge 2 dataframe into one:
    cate_df = fraud.merge(not_fraud, on = column , how = 'outer')
    cate_df = cate_df.fillna(0)
    cate_df.rename(columns = {count+'_x':'fraud',count+'_y':'not_fraud'}, inplace = True)

    #Caculate the percentage:
    cate_df['%'] = cate_df['fraud']/(cate_df['fraud']+cate_df['not_fraud'])

    return cate_df

# %% [markdown]
# ### Category Features: Features related to card holders (job, dob, city, state)

# %%
# Create a new features: Year of birth
from datetime import datetime

df['dob_year'] = df.apply(lambda x: datetime.strptime(x['dob'], '%Y-%m-%d').year, axis =1)

# %%
df.nunique()
# Out:
# trans_date_trans_time    97609
# cc_num                     983
# merchant                   693
# category                    14
# amt                      25048
# first                      352
# last                       481
# gender                       2
# street                     983
# city                       894
# state                       51
# zip                        970
# lat                        968
# long                       969
# city_pop                   879
# job                        494
# dob                        968
# trans_num                97748
# unix_time                97609
# merch_lat                97438
# merch_long               97627
# is_fraud                     2
# tns_hour                    24
# dob_year                    81
# dtype: int64

# %% [markdown]
# Since the category columns have many values (job, city, state,..), we will calculate the percentage of fraud transaction for each values in that features, and plot the boxplot to see whether any outliers (outliers in this mean will show us there're some values have high fraud ratio and can be insightful)

# %%
cols = ['job','state','city','dob_year'] #excluded columns with the same meaning

plt.figure(figsize=(10, 8))

for i, col in enumerate(cols, 1):
    cate_df = count_percentage_cc(df, col, 'is_fraud','cc_num') #apply the function to calculate the fraud ratio
    plt.subplot(len(cols), 1, i)
    sns.boxplot(data = cate_df, y='%')
    plt.title(f'Fraud ratio Distribution of {col}')
    plt.xlabel('Value')
    plt.ylabel('Fraud Ratio')

plt.tight_layout()
plt.show()

# %% [markdown]
# All of this features have some highest values as outliers &#8594; should check each of them

# %% [markdown]
# #### JOB: not related to fraud card number

# %%
job_df = count_percentage_cc(df,'job','is_fraud','cc_num')
job_df.sort_values(by=['%','fraud'], ascending = False).head(5)
# Out:
#                                    job  fraud  not_fraud    %
# 89              Air traffic controller    2.0        0.0  1.0
# 187                             Dancer    2.0        0.0  1.0
# 209  Sales promotion account executive    2.0        0.0  1.0
# 224                 Veterinary surgeon    1.0        0.0  1.0
# 232                  Personnel officer    1.0        0.0  1.0

# %%
job_df.sort_values(by='fraud', ascending = False).head(5)
# Out:
#                          job  fraud  not_fraud         %
# 0    Copywriter, advertising    6.0        4.0  0.600000
# 2  Trading standards officer    6.0        4.0  0.600000
# 1         Materials engineer    6.0        6.0  0.500000
# 3        Exhibition designer    5.0        5.0  0.500000
# 4            Naval architect    5.0        6.0  0.454545

# %% [markdown]
# As we see from 2 tables:
# * Job values with % = 1 has very small number of card number fraud (1, and 2)
# * Job values with high number of fraud has nearly 50/50 chance of fraud (fraud ratio = 60%)
#
# &#8594; JOB is not related to fraud card number

# %% [markdown]
# #### STATE: not related to fraud card number

# %%
state_df = count_percentage_cc(df,'state','is_fraud','cc_num')
state_df.sort_values(by=['%','fraud'], ascending = False).head(5)
# Out:
#    state  fraud  not_fraud         %
# 47    DE      1        0.0  1.000000
# 43    AK      3        2.0  0.600000
# 41    NV      5        4.0  0.555556
# 22    TN     15       13.0  0.535714
# 14    NC     17       17.0  0.500000

# %%
state_df.sort_values(by='fraud', ascending = False).head(5)
# Out:
#   state  fraud  not_fraud         %
# 0    NY     56       61.0  0.478632
# 1    TX     51       60.0  0.459459
# 2    PA     46       53.0  0.464646
# 3    CA     37       40.0  0.480519
# 4    OH     32       38.0  0.457143

# %% [markdown]
# The same pattern with JOB feature &#8594; STATE is not related to fraud card number

# %% [markdown]
# #### CITY: not related to fraud card number

# %%
city_df = count_percentage_cc(df,'city','is_fraud','cc_num')
city_df.sort_values(by=['%','fraud'], ascending = False).head(5)
# Out:
#            city  fraud  not_fraud    %
# 57   North East    1.0        0.0  1.0
# 60      Norfolk    1.0        0.0  1.0
# 63  Noblesville    1.0        0.0  1.0
# 65    Nicholson    1.0        0.0  1.0
# 93  Orange Park    1.0        0.0  1.0

# %%
city_df.sort_values(by='fraud', ascending = False).head(5)
# Out:
#              city  fraud  not_fraud         %
# 0         Houston    4.0        2.0  0.666667
# 6          Dallas    3.0        4.0  0.428571
# 1        Lakeland    3.0        3.0  0.500000
# 10  New York City    3.0        3.0  0.500000
# 8          Warren    3.0        3.0  0.500000

# %% [markdown]
# The same pattern with JOB feature &#8594; STATE is not related to fraud card number

# %% [markdown]
# #### YEAR OF BIRTH: not related to fraud card number

# %%
year_df = count_percentage_cc(df,'dob_year','is_fraud','cc_num')
year_df.sort_values(by=['%','fraud'], ascending = False).head(5)
# Out:
#     dob_year  fraud  not_fraud         %
# 78      1925    1.0        0.0  1.000000
# 51      1996    7.0        3.0  0.700000
# 47      1940    8.0        5.0  0.615385
# 54      1934    6.0        4.0  0.600000
# 72      1938    3.0        2.0  0.600000

# %%
year_df = count_percentage_cc(df,'dob_year','is_fraud','cc_num')
year_df.sort_values(by=['%','fraud'], ascending = False).head(5)
# Out:
#     dob_year  fraud  not_fraud         %
# 78      1925    1.0        0.0  1.000000
# 51      1996    7.0        3.0  0.700000
# 47      1940    8.0        5.0  0.615385
# 54      1934    6.0        4.0  0.600000
# 72      1938    3.0        2.0  0.600000

# %% [markdown]
# The same pattern with JOB feature &#8594; STATE is not related to fraud card number

# %% [markdown]
# #### GENDER: not related to fraud

# %%
gender_df = count_percentage_cc(df,'gender','is_fraud','cc_num')
gender_df.sort_values(by=['%','fraud'], ascending = False).head(5)
# Out:
#   gender  fraud  not_fraud         %
# 0      M    382        448  0.460241
# 1      F    380        460  0.452381

# %% [markdown]
# The ration between Male and Female nearly the same &#8594; Gender is not related to fraud

# %% [markdown]
# ### Category Features: Features related to merchant (category, merch_lat, merch_long)

# %% [markdown]
# #### DISTANCE FROM CARD HOLDER TRANSACTION TO MERCHANT LOCATION: not related to fraud
#
# We have the hypothesis: the distance between card holder location and merchant location can affect the fraud behavior

# %%
# Calculate the distance:

import math

def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great-circle distance between two points on the Earth.

    Parameters:
    lat1, lon1 - Latitude and longitude of the first point in decimal degrees
    lat2, lon2 - Latitude and longitude of the second point in decimal degrees

    Returns:
    Distance between the two points in kilometers
    """
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = math.sin(dlat / 2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon / 2)**2
    c = 2 * math.asin(math.sqrt(a))

    # Radius of Earth in kilometers. Use 3956 for miles. Determines return value units.
    r = 6371.0

    # Calculate the result
    distance = r * c

    return distance

# %%
df['dist'] = df.apply(lambda x: haversine(x['lat'],x['long'],x['merch_lat'],x['merch_long']), axis =1)

# %%
sns.boxplot(data=df, x='is_fraud', y='dist')
# Out:
# <Axes: xlabel='is_fraud', ylabel='dist'>

# %% [markdown]
# From this boxplot, we see in fraud and non-fraud transactions, they have the same range of distance
#
# &#8594; Reject our hypothesis, distance is not affect the fraud

# %% [markdown]
# #### CATEGORY: related to fraud transaction

# %%
cols = ['category'] #excluded columns with the same meaning

plt.figure(figsize=(8, 6))

for i, col in enumerate(cols, 1):
    cate_df = count_percentage_tns(df, col, 'is_fraud','cc_num') #apply the function to calculate the fraud ratio
    plt.subplot(len(cols), 1, i)
    sns.boxplot(data = cate_df, y='%')
    plt.title(f'Fraud ratio Distribution of {col}')
    plt.xlabel('Value')
    plt.ylabel('Fraud Ratio')

plt.tight_layout()
plt.show()

# %%
cat_df = count_percentage_tns(df,'category','is_fraud','cc_num')
cat_df.sort_values(by=['%','fraud'], ascending = False).head(5)
# Out:
#         category  fraud  not_fraud         %
# 1   shopping_net   1713       6540  0.207561
# 2       misc_net    915       4322  0.174718
# 0    grocery_pos   1743       8425  0.171420
# 3   shopping_pos    843       8208  0.093139
# 4  gas_transport    618       9204  0.062920

# %%
cat_cc_df = count_percentage_cc(df,'category','is_fraud','cc_num')
cat_cc_df.sort_values(by=['%','fraud'], ascending = False).head(5)
# Out:
#         category  fraud  not_fraud         %
# 0    grocery_pos    671        897  0.427934
# 1   shopping_net    662        885  0.427925
# 2       misc_net    515        841  0.379794
# 3   shopping_pos    508        895  0.362081
# 4  gas_transport    427        880  0.326702

# %% [markdown]
# From 2 tables, we can see:
# * Nearly 20% transactions of shopping_net, misc_ner and grocery_pos are fraud
# * 20% transactions in each of 3 values come from nearly 50% card holders
#
# &#8594; Category affect the fraud transaction: shopping_net, misc_ner and grocery_pos

# %% [markdown]
# ### Category Features: Features related to transaction (trans_time)

# %% [markdown]
# #### TRANSACTION HOURS: related to fraud
#
# We have the hypothesis: the time (hour) of transaction can related to fraud

# %%
df['tns_hour'] = df['trans_date_trans_time'].apply(lambda x: pd.to_datetime(x, format = '%Y-%m-%d %H:%M:%S.%f').hour)

# %%
time_df = count_percentage_tns(df,'tns_hour','is_fraud','cc_num')
sns.barplot(data=time_df, x='tns_hour', y='%')
# Out:
# <Axes: xlabel='tns_hour', ylabel='%'>

# %% [markdown]
# From this chart, we see that: From 22 to 4 o'clock: the ratio of fraud transactions is higher than other
#
# &#8594; Transaction hour related to fraud

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We have some insights below for fraud behaviors:
#
# 1. Fraud transactions most have the higher amount of values: (from 200 to 2000)
# 2. Transactions spend on these categories can have higher chance of fraud: shopping_net, misc_net, grocery_pos
# 3. Transactions spend on time between 22 to 4 o'clock can have higher chance of fraud
